# %% [markdown]
# ## Tạo trích xuất đặc trưng và frame của video

# %%
# !python video_forward2.py --makedatasets --dataset data_our/data_h5/data3.h5  --video-dir data_video/data3/ --frm-dir frames
# Out:
# chasing.mp4
# 10073
# Precomputing scatters...
# Inferring best change points...
# Precomputing scatters...
# Inferring best change points...
# 2024-06-21 22:58:27.703630: W tensorflow/core/framework/op_def_util.cc:369] Op BatchNormWithGlobalNormalization is deprecated. It will cease to work in GraphDef version 9. Use tf.nn.batch_normalization().
# 2024-06-21 22:58:27.830898: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE SSE2 SSE3 SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/10073 [00:00<?, ?it/s]2024-06-21 22:58:28.138826: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
#
#
#   0%|          | 1/10073 [00:02<7:45:23,  2.77s/it]
#
# ...

# %% [markdown]
# ## Dùng model đã train trước đó với tập dataset summe và file đặc trưng, frame vừa tạo của video trên để tạo bản tóm tắt

# %%
# !python video_forward2.py --makescore --summary --model log/summe-split0/model_epoch60.pth.tar --dataset data_our/data_h5/data3.h5 --frm-dir frames/chasing --save-dir logs/videolog/ --gpu 0
# Out:
# ...
# Args:Namespace(dataset='data_our/data_h5/data3.h5', fps=30, frm_dir='frames/chasing', gpu='0', height=480, hidden_dim=256, input_dim=1024, makedatasets=False, makescore=True, model='log/summe-split0/model_epoch60.pth.tar', num_layers=1, rnn_cell='lstm', save_dir='logs/videolog/', save_name='summary.mp4', seed=1, split=None, split_id=0, summary=True, train_data=False, use_cpu=False, video_dir=None, width=640)
# ...
# Currently using GPU 0
# Initialize dataset data_our/data_h5/data3.h5
# ['video_1']
# # total videos 1. # test videos 1
# Initialize model
# Model size: 2.62605M
# Loading checkpoint from 'log/summe-split0/model_epoch60.pth.tar'
# Evaluate
# ==> Test
# (10073,)
# Summary
# ['video_1']
